# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Value_of_Energy_Cost_Savings_Program_Savings_for_Businesses_-_FY2020.csv")

# %%
df.head(10)
# Out:
#                                   Company Name     company contact  \
# 0                               1 State Street       David Neiburg
# 1                               100 Church LLC   Edward A. Carroll
# 2                         100 Wall Investments        Jerry Branam
# 3                  1-10 Bush Terminal Owner LP      Andrew Kimball
# 4     120 Broadway Acquisitions JV, LLC (Ldmk)         Carl Letich
# 5                         120 Wall Street, LLC       Jason McCalla
# 6                         139 ACA Realty, Inc.     Eitan Chandally
# 7  141 Lake Avenue Realty c/o JR Produce, Inc.           Josef Raz
# 8                       14-10 123rd Street LLC  Danica/Ivan Drazic
# 9                      183 Lorriane Street LLC        Tom Sapienza
#
#                company email company phone                Address  \
# 0     eskoblo@energyspec.com    7186779077          1114 Avenue J
# 1                        NaN    2125663000      100 Church Street
# ...

# %%
company_number = len(df['Company Name'].unique())

# %%
print("The number different companies represented: ", company_number)
# Out:
# The number different companies represented:  439

# %%
queens_filter = df[df["Borough"] == 'Queens']

# %%
jobs_created_queens = queens_filter['Job created'].sum()

# %%
print("The number of jobs created in Queens: ", jobs_created_queens)
# Out:
# The number of jobs created in Queens:  102.0

# %%
df['email domain'] = df['company email'].str.split('@').str[1]

# %%
df['email domain']
# Out:
# 0        energyspec.com
# 1                   NaN
# 2                   NaN
# 3      industrycity.com
# 4          silvprop.com
#              ...
# 445      wontonfood.com
# 446           gmail.com
# 447            wwps.com
# 448    wudfurniture.com
# 449          wurtec.com
# Name: email domain, Length: 450, dtype: object

# %%
unique_domains_count = len(df['email domain'].unique())

# %%
print("The number of unique email domains: ", unique_domains_count)
# Out:
# The number of unique email domains:  357

# %%
df.columns.values.tolist()
g1=df[["NTA","Job created","Total Savings"]]
g2nm=g1.groupby(["NTA"])["NTA"].count().index.tolist()
g2=g1.groupby(["NTA"])["NTA"].count()
indref=np.zeros(79)
for i in range(79):
  if g2[i]>=5:
    indref[i]=1;
g4 = pd.DataFrame(
    {
        "NTA": [],
        "Avg Total Savings": [],
        "Total Jobs created": [],
    }
)

jbs=np.zeros(79)
tsav=np.zeros(79)
for i in range(79):
  if g2[i]>=5:
    g3=g1[g1["NTA"]==g2nm[i]].index
    jbs[i]=g1.iloc[g3,1].sum()
    tsav[i]=g1.iloc[g3,2].mean()
    g4.loc[len(g4.index)]=[g2nm[i], tsav[i], jbs[i]]

g4.to_csv('Day4.csv',index=False)
